# %%
#Programming question 2 : T-sne

# %%
# %matplotlib inline
from sklearn import datasets
from sklearn.manifold import TSNE
import seaborn as sns
import pandas as pd

digits = datasets.load_digits()

X = digits.data
y = digits.target
tsne = TSNE(n_components=2, random_state=0,perplexity = 30,n_iter = 1000)
X_2d = tsne.fit_transform(X)
tsne_df = pd.DataFrame({'X':X_2d[:,0],
                        'Y':X_2d[:,1],
                        'digit':y})

sns.scatterplot(x="X", y="Y",
              hue="digit",
              palette=['purple','red','orange','brown','blue',
                       'dodgerblue','green','lightgreen','darkcyan', 'black'],
              legend='full',
              data=tsne_df).set_title("T-Sne for no. of iteration=1000")
# Out:
# Text(0.5, 1.0, "'T-Sne for no. of iteration=1000'")

# %%
# %matplotlib inline

tsne = TSNE(n_components=2, random_state=0,perplexity = 30,n_iter = 250)
X_2d = tsne.fit_transform(X)
tsne_df = pd.DataFrame({'X':X_2d[:,0],
                        'Y':X_2d[:,1],
                        'digit':y})

sns.scatterplot(x="X", y="Y",
              hue="digit",
              palette=['purple','red','orange','brown','blue',
                       'dodgerblue','green','lightgreen','darkcyan', 'black'],
              legend='full',
              data=tsne_df).set_title("T-Sne for no. of iteration=250")
# Out:
# Text(0.5, 1.0, 'T-Sne for no. of iteration=250')

# %%
# %matplotlib inline
tsne = TSNE(n_components=2, random_state=0,perplexity = 30,n_iter = 2000
           )
X_2d = tsne.fit_transform(X)
tsne_df = pd.DataFrame({'X':X_2d[:,0],
                        'Y':X_2d[:,1],
                        'digit':y})

sns.scatterplot(x="X", y="Y",
              hue="digit",
              palette=['purple','red','orange','brown','blue',
                       'dodgerblue','green','lightgreen','darkcyan', 'black'],
              legend='full',
              data=tsne_df).set_title("T-Sne for no. of iteration=2000")
# Out:
# Text(0.5, 1.0, 'T-Sne for no. of iteration=2000')
